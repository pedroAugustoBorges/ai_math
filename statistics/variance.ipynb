# %% [markdown]
# #### Variance ($\sigma^2$)

# %% [markdown]
# $$\sigma^2 = \frac{\sum_{i=1}^{n} (x_i - \bar{x})^2}{n}$$

# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Variance Implementation (No Numpy)

# %%
a = [4, 5, 6]
b = [1, 5, 9]

# %%
def mean_calculate(l):

    mean = 0
    for i in l:
        mean+= i / len(l)

    return mean

# %%
mean_a = mean_calculate(a)
mean_b = mean_calculate(b)

# %%
mean_a
# Out:
# 5.0

# %%
def centering(l, mean):
    new_observations = []
    for x in l:
        new_observations.append(((x - mean ) ** 2))

    return new_observations

# %%
centering_values_a = centering(a, mean_a)
centering_values_b = centering(b, mean_b)

# %%
print('centering_values_a:' ,centering_values_a)
print('centering_values_b:' ,centering_values_b)
# Out:
# centering_values_a: [1.0, 0.0, 1.0]
# centering_values_b: [16.0, 0.0, 16.0]

# %%
def variance(center):
    return sum(center) / len(center)

# %%
var_a = variance(centering_values_a)
var_b = variance(centering_values_b)

# %%
print('var_a:' ,var_a)
print('var_b' ,var_b)
# Out:
# var_a: 0.6666666666666666
# var_b 10.666666666666666

# %%
var_b
# Out:
# 10.666666666666666

# %% [markdown]
# ### Covariance Implementation (NumPy)

# %%
variance_np = np.var(a)

# %%
variance_np
# Out:
# np.float64(0.6666666666666666)
