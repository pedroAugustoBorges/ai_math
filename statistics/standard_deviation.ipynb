# %% [markdown]
# ## Standard Deviation

# %% [markdown]
# $$\sigma = \sqrt{\frac{\sum_{i=1}^{n} (x_i - \bar{x})^2}{n}}$$

# %%
import pandas
import numpy as np
import math

# %%
a = [14, 2, 5]
b = [9, 5, 10]

a_n = len(a)

# %%
def mean_calculate(l):

    mean = 0
    for i in l:
        mean+= i / len(l)

    return mean

# %%
a_mean = mean_calculate(a)

# %%
a_mean
# Out:
# 7.000000000000001

# %%
def deviation(xi, mean):
    return [(value - mean) for value in xi]

# %%
a_deviation = deviation(xi= a, mean=a_mean)

# %%
print(a_deviation)
# Out:
# [6.999999999999999, -5.000000000000001, -2.000000000000001]

# %%
def pow_numbers(xi):
    return [(value ** 2) for value in xi]

# %%
a_pow = pow_numbers(a_deviation)

# %%
print(a_pow)
# Out:
# [48.999999999999986, 25.000000000000007, 4.0000000000000036]

# %%
def sum_numbers(xi):
    aux = 0
    for x in xi:
        aux += x
    return aux

# %%
a_sum = sum_numbers(a_pow)

# %%
print(a_sum)
# Out:
# 78.0

# %%
variance = a_sum / a_n

# %%
def square(xi):
    return xi ** 0.5

# %%
standard_deviation = square(variance)

# %%
print(standard_deviation)
# Out:
# 5.0990195135927845

# %% [markdown]
# ### Standard Deviation Implementation (NumPy)

# %%
std_np = np.std(a)

# %%
std_np
# Out:
# np.float64(5.0990195135927845)
