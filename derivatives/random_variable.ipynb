# %% [markdown]
# # Random Variable

# %% [markdown]
# ## What's random variable?
#
# Random variable is the rule mapping outcome to numbers given a set of data sample\
# So... What it really means?
#
# Let's suppose you have a six-sided die, what's the probability the outcome is 3, for instace?

# %% [markdown]
# ### Sample Space
#
# dice = [1, 2, 3, 4, 5, 6]
#
# Random variable can be any numbers above because outcome is non determinist and that must has a number associated with it\
